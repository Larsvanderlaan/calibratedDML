# %% [markdown]
# # Supplied nuisance matrices
#
# This notebook mirrors the direct nuisance workflow and includes a multi-arm alignment example.

# %%
from supplied_nuisances import run_tutorial

results = run_tutorial()

# %%
results["binary_supplied"]

# %%
results["multiarm_supplied"]
