# %% [markdown]
# # Adaptive binary-treatment workflow
#
# This notebook mirrors the advanced adaptive tutorial and keeps the adaptive track separate from the standard estimator tutorials.

# %%
from adaptive_binary_treatment import run_tutorial

results = run_tutorial()

# %%
results["calibrated_rlearner"]

# %%
results["plugin"]
