# %% [markdown]
# # Custom learners
#
# This notebook mirrors the Python custom-learner tutorial and compares built-in strings with sklearn-compatible estimators.

# %%
from custom_learners import run_tutorial

results = run_tutorial()

# %%
results["builtin"]

# %%
results["custom"]
