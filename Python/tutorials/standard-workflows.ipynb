# %% [markdown]
# # Standard workflows
#
# This notebook mirrors the standard raw-data workflow script and keeps the examples small enough for CI.

# %%
from standard_workflows import run_tutorial

results = run_tutorial()

# %%
results["binary_wald"]

# %%
results["multiarm_jackknife"]
